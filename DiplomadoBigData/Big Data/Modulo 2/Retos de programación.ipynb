# %% [markdown]
# <img src = "https://raw.githubusercontent.com/HarryVargas96/UdeCataluna/main/logo_uc_grande.png" alt = "Encabezado" width = "100%">  </img>

# %% [markdown]
# # **Retos de programación**

# %% [markdown]
# A continuación se proponen una serie de ejercicios prácticos para que rete sus conocimientos adquiridos durante el módulo. Puede añadir estos ejercicios a sus apuntes. **Estos ejercicios son opcionales.**

# %% [markdown]
# ## **Calificaciones**
#
# Escribe un programa que solicite una puntuación entre 0.0 y 1.0. Si la
# puntuación está fuera de ese rango, muestra un mensaje de error. Si la puntuación
# está entre 0.0 y 1.0, muestra la calificación usando la tabla siguiente:
#
#
# | Puntuación | Calificación |
# | ---------| -----------|
# |>= 0.9 |Sobresaliente|
# |>= 0.8| Notable|
# |>= 0.7 |Bien|
# |>= 0.6 |Suficiente|
# |< 0.6 |Insuficiente|
#
# ```
# Introduzca puntuación: 0.95
# Sobresaliente
# Introduzca puntuación: perfecto
# Puntuación incorrecta
# Introduzca puntuación: 10.0
# Puntuación incorrecta
# Introduzca puntuación: 0.75
# Bien
# Introduzca puntuación: 0.5
# Insuficiente
# ```

# %%
calificacion = float(input('Introduzca su puntuación: '))

if calificacion >= 0 and calificacion < 0.6:
  print('Insuficiente')
elif calificacion >= 0.6 and calificacion < 0.7:
  print('Suficiente')
elif calificacion >= 0.7 and calificacion < 0.8:
  print('Bien')
elif calificacion >= 0.8 and calificacion < 0.9:
  print('Notable')
elif calificacion >= 0.9 and calificacion <= 1.0:
  print('Sobresaliente')
else:
  print('Puntuación incorrecta')
# Out:
# Introduzca su puntuación: 5
# Puntuación incorrecta

# %%
calificacion = float(input('Introduzca su puntuación: '))

if 0 <= calificacion < 1:
    niveles = ['Insuficiente', 'Suficiente', 'Bien', 'Notable', 'Sobresaliente']
    indice = max(int(calificacion * 10), 5) - 5
    print(niveles[indice])
elif calificacion == 1:
    print('Sobresaliente')
else:
    print('Puntuación incorrecta')
# Out:
# Introduzca su puntuación: 1
# Sobresaliente

# %%
calificacion = float(input('Introduzca su puntuación: '))

if 0 <= calificacion < 1:
    niveles = ['Insuficiente', 'Suficiente', 'Bien', 'Notable', 'Sobresaliente']
    indice = max(int(calificacion * 10 - 5), 0)
    print(niveles[indice])
elif calificacion == 1:
    print('Sobresaliente')
else:
    print('Puntuación incorrecta')
# Out:
# Introduzca su puntuación: 0.6
# Suficiente

# %%
calificacion = float(input('Introduzca su puntuación: '))

if 0 <= calificacion <= 1:
    niveles = ['Insuficiente', 'Suficiente', 'Bien', 'Notable', 'Sobresaliente']
    indice = min(max(int(calificacion * 10 - 5), 0), 4)
    print(niveles[indice])
else:
    print('Puntuación incorrecta')
# Out:
# Introduzca su puntuación: 1.2
# Puntuación incorrecta

# %% [markdown]
# ## **Salario**
#
# Escriba una función que solicite número de horas trabajadas a la semana y retorne el salario del trabajador. Si el trabajador laboró por 40 horas o menos, el pago por hora será de 15.000. Para las horas extra trabajadas (más de 40 horas a la semana) el pago por hora será de 21.000.
#
# ```
# Input: 35
# Out: 'Su pago es de: 525000 pesos'
#
# Input: 40
# Out: 'Su pago es de: 600000 pesos'
#
# Input: 48
# Out: 'Su pago es de: 768000 pesos'
# ```

# %%
horas_trabajadas = int(input('Ingrese las horas trabajadas: '))

if 0 <= horas_trabajadas <= 40:
  salario = horas_trabajadas * 15000
  print('Su pago es de: ' + str(salario))
elif horas_trabajadas > 40:
  salario = 40 * 15000 + (horas_trabajadas - 40) * 21000
  print('Su pago es de: ' + str(salario))
# Out:
# Ingrese las horas trabajadas: 48
# Su pago es de: 768000

# %%
horas_trabajadas = int(input('Ingrese las horas trabajadas: '))

salario = horas_trabajadas * 15000 if 0 <= horas_trabajadas <= 40 else 40 * 15000 + (horas_trabajadas - 40) * 21000

print(f'Su pago es de: {salario}')
# Out:
# Ingrese las horas trabajadas: 48
# Su pago es de: 768000

# %% [markdown]
# ## **La secuencia Collatz**
#
# Escriba una función llamada ``collatz()`` que tenga un solo parámetro llamado ``número``.
#
# Si ``número`` es par, ``collatz()`` debe imprimir ``número // 2`` y retornar este valor.
#
# Si ``número`` es impar, ``collatz()`` debe imprimir y retornar ``3 * número + 1`` .
#
# Ahora escriba un programa que le pida al usuario un número entero, y que llame a la función  ``collatz()`` tantas veces como sea necesario hasta que la salida sea 1. Tarde o temprano, para cualquier número entero la salida siempre será 1.
#
# La salida de este programa se ve más o menos así.
#
# ```
# In: 6
# Out:
# 3
# 10
# 5
# 16
# 8
# 4
# 2
# 1
# ```

# %%
numero = int(input('Escriba un número entero positivo: '))

def collatz(n):
  if numero == 1:
    print(f'{n}')
  while n!= 1:
    n = n//2 if n%2 == 0 else 3 * n + 1
    print(f'{n}')

collatz(numero)
# Out:
# Escriba un número entero positivo: 6
# 3
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %%
def collatz(n):
    if n == 1:
        print(n)
    while n != 1:
        n = n // 2 if n % 2 == 0 else 3 * n + 1
        print(n)

while True:
    try:
        numero = int(input('Escriba un número entero positivo: '))
        if numero > 0:
            break
        print("Número inválido. Debe ser mayor a 0.")
    except ValueError:
        print("Entrada inválida. Ingrese un número entero.")

collatz(numero)
# Out:
# Escriba un número entero positivo: 1
